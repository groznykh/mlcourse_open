# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('hw1scores.csv')
hw1 = df['ДЗ1']
hw1.describe()
# Out:
# count    1238.000000
# mean        8.346527
# std         1.715482
# min         1.000000
# 25%         8.000000
# 50%         8.000000
# 75%        10.000000
# max        10.000000
# Name: ДЗ1, dtype: float64

# %%
sns.distplot(hw1)
plt.show()
